# %%
#make a map to see directions

leyte <- c(124.66341697234651, 10.64608339564836, 124.79451387519741, 10.926865732684925) # site areas
leyteDF <- as.data.frame(as.matrix(leyte))
col <- "value"
colnames(leyteDF) <- col
leyteDF$vertex <- c("lowerleft", "lowerleft", "upperright", "upperright")
leyteDF$axis <- c("lon", "lat", "lon", "lat")
leyteDF <- leyteDF %>% spread(axis, value)

singlepoint <- c(lon=124.757607, lat=10.747310)

#mymap <- get_googlemap(center = c(124.757607, 10.747310))



my_map3 <- get_stamenmap(location=c(lon=124.757607, lat=10.747310), source="osm")
#ylims = c(10.63, 10.87)

#sing <- get_map(location = "singapore", color = "bw",
#                zoom = 11, maptype = "toner", source = "google")
#
## This is a pseudo tweets data frame including long and lat only
#set.seed(12)
#foo <- data.frame(long = runif(300, 103.68, 104),
#                  lat = runif(300, 1.3, 1.42))
#
#ggmap(sing) +
#geom_point(data = foo, aes(x = long, y = lat), color = "red")
#
ggmap(my_map3)# +
#geom_point(aes(x = lon, y = lat), data = leyteDF, alpha = .5, color="darkred", size = 3)
# Out:
# Warning message in get_stamenmap(location = c(lon = 124.757607, lat = 10.74731), :
# “location is not a valid argument to get_stamenmap(); it is ignored.”
# plot without title

# %%
ggplot(data = world) +
  geom_sf(fill= "gray90") +
  labs( x = "Longitude", y = "Latitude") +
  coord_sf(xlim = c(100.00, 180.00), ylim = c(-45.00, -10.00), expand = FALSE) +
  annotation_scale(location = "bl", width_hint = 0.5) +
  annotation_north_arrow(location = "bl", which_north = "true", 
                         pad_x = unit(0.75, "in"), pad_y = unit(0.5, "in"),
                         style = north_arrow_fancy_orienteering) +
  coord_sf(xlim = c(100.00, 180.00), ylim = c(-45.00, -10.00)) +
   theme(panel.grid.major = element_line(color = "gray60", linetype = "dashed", size = 0.25), 
         panel.background = element_rect(fill = "aliceblue")) +
  geom_text(data= world_points,aes(x=X, y=Y, label=name),
            color = "gray20", fontface = "italic", check_overlap = T, size = 3)

# %%
#AIzaSyCVA_9W7kNHKPH3__9BOSiuLZvVEPvO1IA
#showing_key()
#ggmap_show_api_key()
register_google(key="AIzaSyCVA_9W7kNHKPH3__9BOSiuLZvVEPvO1IA", write=T)
# Out:
# Creating file /local/home/katrinac/.Renviron
# Adding key to /local/home/katrinac/.Renviron
