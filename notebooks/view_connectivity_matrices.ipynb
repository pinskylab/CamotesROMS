# %% [markdown]
# ## read in Liz's first passes at ROMS simulations, see if they make sense. If they do, we can proceed.

# %%
.nc
Camotes_Sea_Connectivity_Matrices_15_day_PLD.nc

# %%
#import necessary libraries

import numpy as np
from netCDF4 import Dataset

# %%
data = Dataset('/local/home/katrinac/oceanography/Camotes_Sea_Connectivity_Matrices_08_day_PLD.nc',mode='r') # Load netcdf file

# %%
print data.file_format
# Out:
# NETCDF4

# %%
print data.dimensions.keys()
# Out:
# [u'time', u'time_len', u'source', u'src_len', u'sink']

# %%
print data.dimensions['time']
print data.dimensions['time_len']
print data.dimensions['src_len']
# Out:
# <type 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 930
#
# <type 'netCDF4._netCDF4.Dimension'>: name = 'time_len', size = 10
#
# <type 'netCDF4._netCDF4.Dimension'>: name = 'src_len', size = 17

# %%
 print data.variables.keys()
# Out:
# [u'date_string', u'source_region', u'connectivity_fraction']

# %%
date = data.variables['date_string'][:]
source = data.variables['source_region'][:]
conn_frac = data.variables['connectivity_fraction'][:]

# %%
data.close()

# %%
import matplotlib.pyplot as plt

# %%
print source
# Out:
# [[u'P' u'a' u'l' u'a' u'n' u'a' u's' u'' u'' u'' u'' u'' u'' u'' u'' u''
#   u'']
#  [u'W' u'a' u'n' u'g' u'a' u'g' u'' u'' u'' u'' u'' u'' u'' u'' u'' u''
#   u'']
#  [u'M' u'a' u'g' u'b' u'a' u'n' u'g' u'o' u'n' u'' u'' u'' u'' u'' u''
#   u'' u'']
#  [u'C' u'a' u'b' u'a' u't' u'o' u'a' u'n' u'' u'' u'' u'' u'' u'' u'' u''
#   u'']
#  [u'C' u'a' u'r' u'i' u'd' u'a' u'd' u'_' u'C' u'e' u'm' u'e' u't' u'e'
#   u'r' u'y' u'']
#  [u'C' u'a' u'r' u'i' u'd' u'a' u'd' u'_' u'P' u'r' u'o' u'p' u'e' u'r'
#   u'' u'' u'']
#  [u'H' u'i' u'c' u'g' u'o' u'p' u'' u'' u'' u'' u'' u'' u'' u'' u'' u''
#   u'']
#  [u'H' u'i' u'c' u'g' u'o' u'p' u'_' u'S' u'o' u'u' u't' u'h' u'' u'' u''
#   u'' u'']
#  [u'S' u'i' u't' u'i' u'o' u'_' u'T' u'u' u'g' u'a' u's' u'' u'' u'' u''
#   u'' u'']
#  [u'E' u'l' u'e' u'm' u'e' u'n' u't' u'a' u'r' u'y' u'_' u'S' u'c' u'h'
#   u'o' u'o' u'l']
#  [u'S' u'i' u't' u'i' u'o' u'_' u'L' u'o' u'n' u'a' u's' u'' u'' u'' u''
#   u'' u'']
# ...

# %%
plt.plot(source,conn_frac, date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9402169e563c> in <module>()
# ----> 1 plt.plot(source,conn_frac, date)
#
# /local/home/katrinac/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# /local/home/katrinac/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...
